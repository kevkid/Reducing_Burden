# %% [markdown]
# # Padchest Unimodal

# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np
import ast
from utils import *
from sklearn import preprocessing, metrics
import json
from keras.backend import squeeze, expand_dims
from sklearn.metrics import roc_auc_score
from keras.models import load_model
# Out:
# Using TensorFlow backend.

# %%
#Pipeline Parameters
createEmbeddings = False
createFolds = True
onlyPhysicianLabels = True
projection = 'PA'
workers = 3
n_epochs = 80
image_loc = '/gpfs/ysm/home/kl533/krauthammer_partition/padchest_2019_small/images-224/'
fitVerbose = 0
with open('n_splits.json') as json_file:
    json_data = json.load(json_file)
n_splits = json_data['n_splits']

# %%
#word2vec parameters
w2v_params = {'vocabulary_size':10000, 'window_size':5,'filters':'','vector_dim':224}
#parameters
max_text_len = 200#this is the same size as the sequence length
vocabulary_size = 10000
embedding_output_dim = 224
shape=(224,224,1)
channels = shape[-1]

# %%
#build our clean csv
#%run -i 'python3 extract_cohort.py' '/gpfs/ysm/home/kl533/krauthammer_partition/padchest_2019_small/PADCHEST_chest_x_ray_images_labels_160K_01.02.19.csv' '/gpfs/ysm/home/kl533/krauthammer_partition/padchest_2019_small/PADCHEST_CLEAN.csv' '/gpfs/ysm/home/kl533/krauthammer_partition/padchest_2019_small/images-224/'
#load already setup csv, with clean labels
df = pd.read_csv('/gpfs/ysm/pi/krauthammer/kl533/padchest_2019_small/PADCHEST_CLEAN.csv')

#lets only pull the labels done by physicians:
if onlyPhysicianLabels:
    pattern = 'Physician'
    df = df[df['MethodLabel'] == pattern]

df['Report'] = df['Report'].apply(lambda x: x if type(x) == str else '')#fix any reports that are na

# %%
l = df.groupby('StudyID').first()['Clean_Labels'].apply(lambda x: ast.literal_eval(x)).to_list()
#list(set([item for sublist in l for item in sublist]))

# %%
label_counts = {}
for ll in l:
    for label in ll:
        if label in label_counts:
            label_counts[label] += 1
        else:
            label_counts[label] = 1
label_counts['other'] = 0
to_del = []
for k,v in label_counts.items():
    if v < 400:
        label_counts['other'] += v
        to_del.append(k)
for key in to_del: del label_counts[key]
#print(label_counts)
#print(len(label_counts))

# %%
label_counts
# Out:
# {'normal': 3056,
#  'cardiomegaly': 753,
#  'COPD signs': 1072,
#  'infiltrates': 964,
#  'aortic elongation': 621,
#  'thoracic cage deformation': 1028,
#  'atelectasis': 447,
#  'pneumonia': 490,
#  'air trapping': 509,
#  'vertebral degenerative changes': 743,
#  'other': 6364}

# %%
df['Final_Labels'] = df['Clean_Labels'].apply(lambda x: [t if t in label_counts.keys() else 'other' for t in ast.literal_eval(x)])

# %%
num_class = len(label_counts)

# %%
if createEmbeddings:
    print('Section 0.5: create embeddings')
    from w2v_keras import w2v_keras
    w2v = w2v_keras(**w2v_params)
    w2v.fit(df['Report'], epochs=20)
    w2v.save_embeddings('w2v_embeddings_spanish.json')

# %% [markdown]
# ## Build our tokenizer to pass into generators

# %%
tokenizer = Tokenizer(num_words = 10000, lower=True, filters='')#make this a param
tokenizer.fit_on_texts(filter_sentences_spanish(df['Report'].tolist()))
# Out:
# filtering sentences
# filtering sents and removing stopwords

# %%
mlb = preprocessing.MultiLabelBinarizer()
mlb.fit(df['Final_Labels'].to_list())
# Out:
# MultiLabelBinarizer(classes=None, sparse_output=False)

# %% [markdown]
# ### Load Embeddings from JSON file and map tokens to embedding

# %%
#load embedding weights from file
location = 'w2v_embeddings_spanish.json'
import json
with open(location) as f:
    embs = json.load(f)
    emb = json.loads(embs)
embedding_weights = mapTokensToEmbedding(emb, tokenizer.word_index, 
                                         vocabulary_size)

# %%
from keras_applications.resnet_v2 import ResNet50V2
from keras_applications.densenet import DenseNet121
from keras.layers import GlobalAveragePooling2D, Dense
from keras import Sequential
def DenseNetModelFactory():
    model = DenseNet121(input_shape=shape, include_top=False, weights=None,backend=keras.backend,
        layers=keras.layers,
        models=keras.models,
        utils=keras.utils)
    return model

# %%
from keras.models import Model
from keras.layers import Dense, Reshape, concatenate, Lambda, Average, Maximum, Add, Multiply, Concatenate, BatchNormalization, Activation, GlobalAveragePooling2D, GlobalAveragePooling1D, Flatten
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from keras.layers.embeddings import Embedding
from keras.engine.input_layer import Input
from keras.optimizers import Adam
from keras.activations import relu


def Generate_Model(model_type = 'LateFusion'):
    #set up our text input
    if model_type == 'LateFusion':
        input_text = Input(shape=(max_text_len,), name='text_input')
        embedding = Embedding(input_length=max_text_len, input_dim=vocabulary_size, output_dim=embedding_output_dim, 
                               name='embedding_layer', trainable=False, weights=[embedding_weights])
        text_embedding = embedding(input_text)
        #set up our image branch
        image_input = Input(shape, name='image_input')
        image_branch = DenseNetModelFactory()(image_input)
        image_branch = Flatten()(image_branch)
        image_branch = Dense(1024, activation='relu', name='dense_layer1_image_branch')(image_branch)
        image_branch = BatchNormalization()(image_branch)
        image_branch = Dropout(0.5)(image_branch)        
        image_branch = Dense(512, activation='relu', name='dense_layer2_image_branch')(image_branch)
        image_branch = BatchNormalization()(image_branch)
        image_branch = Dropout(0.5)(image_branch)
        image_branch_out = Dense(num_class, activation='sigmoid', name='image_branch_output')(image_branch)
        image_branch_model = Model(inputs=[image_input], outputs=[image_branch_out])
        #set up text branch
        text_branch = get_text_branch()(text_embedding)
        text_branch = Dense(1024, activation='relu', name='dense_layer1_text_branch')(text_branch)
        text_branch = BatchNormalization()(text_branch)
        text_branch = Dropout(0.5)(text_branch)        
        text_branch = Dense(512, activation='relu', name='dense_layer2_text_branch')(text_branch)
        text_branch = BatchNormalization()(text_branch)
        text_branch = Dropout(0.5)(text_branch)
        text_branch_out = Dense(num_class, activation='sigmoid', name='text_branch_output')(text_branch)
        text_branch_model = Model(inputs=[input_text], outputs=[text_branch_out])
        outputs = [model.outputs[0] for model in [text_branch_model, image_branch_model]]
        output = Average()(outputs)
        classificationModel = Model(inputs=[text_branch_model.input, image_branch_model.input], outputs=[output])
    if model_type == "EarlyFusion":
        input_text = Input(shape=(max_text_len,), name='text_input')
        embedding = Embedding(input_length=max_text_len, input_dim=vocabulary_size, output_dim=embedding_output_dim, 
                               name='embedding_layer', trainable=False, weights=[embedding_weights])
        embedded_text = embedding(input_text)
        #expand dims if channel = 1 as we need (height, width, channels) 
        #and a matrix with one channel only has 2 dims
        if channels == 1:
            expandedText = Lambda(lambda x: expand_dims(x, axis=-1))
            embedded_text = expandedText(embedded_text)
        else:
            embedded_text = Lambda(embedding_3Ch)(embedded_text)
        #set up our image input
        image_input = Input(shape, name='image_input')
        '''merge our data for early fusion. Essentially we are just concatenating our data together'''
        merged = concatenate([embedded_text, image_input], axis=1, name='merged')
        x = DenseNetModelFactory()(merged)
        x = Flatten()(x)
        x = Dense(1024, activation='relu', name='dense_layer1_earlyFusion')(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)        
        x = Dense(512, activation='relu', name='dense_layer2_earlyFusion')(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        output = Dense(num_class, activation='sigmoid', name='output')(x)
        classificationModel = Model(inputs=[input_text, image_input], outputs=[output])
    if model_type == "EarlyFusion_Wide":
        input_text = Input(shape=(max_text_len,), name='text_input')
        embedding = Embedding(input_length=max_text_len, input_dim=vocabulary_size, output_dim=embedding_output_dim, 
                               name='embedding_layer', trainable=False, weights=[embedding_weights])
        embedded_text = embedding(input_text)
        #set up our image input
        image_input = Input(shape, name='image_input')
        image_input_reshaped = Reshape((shape[0]*channels,shape[0]))(image_input)#224 is because we have a 224x224 image with 2 channels, 224x1 channels = 224
        '''merge our data for early fusion. Essentially we are just concatenating our data together'''
        merged = concatenate([embedded_text, image_input_reshaped], axis=1, name='merged')
        x = get_text_branch()(merged)
        x = Dense(1024, activation='relu', name='dense_layer1')(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)        
        x = Dense(512, activation='relu', name='dense_layer2')(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        output = Dense(num_class, activation='sigmoid', name='output')(x)
        classificationModel = Model(inputs=[input_text, image_input], outputs=[output])        
    if model_type == 'ModelFusion':
        input_text = Input(shape=(max_text_len,), name='text_input')
        embedding = Embedding(input_length=max_text_len, input_dim=vocabulary_size, output_dim=embedding_output_dim, 
                               name='embedding_layer', trainable=False, weights=[embedding_weights])
        text_embedding = embedding(input_text)
        image_input = Input(shape, name='image_input')
        txt = get_text_branch()            
        #set up our image branch
        image_branch = DenseNetModelFactory()(image_input)
        image_branch = Flatten()(image_branch)
        #set up text branch
        text_branch = (txt)(text_embedding)
        #add some dense layers as test
        x = concatenate([image_branch, text_branch])
        x = Dense(1024, activation='relu', name='dense_layer1_modelFusion')(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)        
        x = Dense(512, activation='relu', name='dense_layer2_modelFusion')(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        #add some dense layers as test
        output = Dense(num_class, activation='sigmoid', name='output')(x)
        classificationModel = Model(inputs=[input_text, image_input], outputs=[output])
    if model_type == "text_1d":#text_1d only
        input_text = Input(shape=(max_text_len,), name='text_input')
        embedding = Embedding(input_length=max_text_len, input_dim=vocabulary_size, output_dim=embedding_output_dim, 
                               name='embedding_layer', trainable=False, weights=[embedding_weights])
        embedded_text = embedding(input_text)
        x = get_text_branch()(embedded_text)
        x = Dense(1024, activation='relu', name='dense_layer1_text_branch')(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)        
        x = Dense(512, activation='relu', name='dense_layer2_text_branch')(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        output = Dense(num_class, activation='sigmoid', name='text_output')(x)
        classificationModel = Model(inputs=[input_text], outputs=[output])
    if model_type == "image":#image only
        image_input = Input(shape, name='image_input')
        x = DenseNetModelFactory()(image_input)
        x = Flatten()(x)
        x = Dense(1024, activation='relu', name='dense_layer1_image_branch')(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)        
        x = Dense(512, activation='relu', name='dense_layer2_image_branch')(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        output = Dense(num_class, activation='sigmoid', name='image_output')(x)
        classificationModel = Model(inputs=[image_input], outputs=[output])
    return classificationModel

# %% [markdown]
# # Set up environment for Models

# %%
#split into train, valid, test of 80-10-10
if createFolds:
    #lets split the arrays
    splitDfs = np.array_split(df, n_splits)
    splits = {}
    for i, split in enumerate(splitDfs):
        train, valid, test = np.split(split[split['Projection'] == projection].sample(frac=1.), [int(.8*len(split[split['Projection'] == projection])), int(.9*len(split[split['Projection'] == projection]))])    
        splits[i] = {}
        splits[i]['train'] = train.index.tolist()
        splits[i]['valid'] = valid.index.tolist()
        splits[i]['test'] = test.index.tolist()
    with open('padchestFolds_{}.json'.format(projection), 'w') as fp:
        json.dump(splits, fp)

# %%
#load folds
with open('padchestFolds_{}.json'.format(projection), 'r') as fp:
    data = json.load(fp)

# %%
chunkList = []
for ix,chunk in data.items():
    chunkList.append(chunk['train'])
    chunkList.append(chunk['valid'])
    chunkList.append(chunk['test'])
for i in range(len(chunkList)):
    for j in range(i+1, len(chunkList)):
        assert len(set(chunkList[i]).intersection(chunkList[j])) == 0, "You have an element from one chunk in another! Each chunk should have unique indicies"

# %%
from keras import backend as K
from sklearn.metrics import hamming_loss
from sklearn.metrics import roc_auc_score
import tensorflow as tf
def full_multi_label_metric(y_true, y_pred):
    comp = K.equal(y_true, K.round(y_pred))
    return K.cast(K.all(comp, axis=-1), K.floatx())
def Hamming_loss(y_true, y_pred):
    return K.cast(hamming_loss(K.eval(y_true), K.round(K.eval(y_pred))), K.floatx())
def auc( y_true, y_pred ) :
    score = tf.py_func( lambda y_true, y_pred : roc_auc_score( y_true, y_pred, average='weighted', sample_weight=None).astype('float32'),
                        [y_true, y_pred],
                        'float32',
                        stateful=False,
                        name='sklearnAUC' )
    return score

# %%
#call back AUC score
#callback code: https://github.com/keras-team/keras/issues/10472#issuecomment-472543538
from sklearn.metrics import roc_auc_score
from keras.callbacks import Callback
class AUC(Callback):
    
    def __init__(self, val_data, batch_size = 8):
        super().__init__()
        self.validation_data = val_data
        self.batch_size = batch_size
    
    def on_train_begin(self, logs={}):
        #print(self.validation_data)
        self.val_f1s = []
        self.val_recalls = []
        self.val_precisions = []
        self._val_auc = []
        
    def on_epoch_end(self, epoch, logs={}):
        batches = len(self.validation_data)
        total = batches * self.batch_size
        y_shape = len(self.validation_data.mlb.classes_)
        val_pred = np.zeros((total, y_shape))
        val_true = np.zeros((total, y_shape))
        
        for batch in range(batches):
            if len(self.validation_data.modality) == 1:
                xVal, yVal = self.validation_data.__getitem__(batch)
                val_pred[batch * self.batch_size : (batch+1) * self.batch_size] = np.asarray(self.model.predict(xVal))
            elif len(self.validation_data.modality) == 2:
                [xValTxt, xValImg], yVal = self.validation_data.__getitem__(batch)
                val_pred[batch * self.batch_size : (batch+1) * self.batch_size] = np.asarray(self.model.predict([xValTxt, xValImg]))
            val_true[batch * self.batch_size : (batch+1) * self.batch_size] = yVal
            
        #val_pred = np.squeeze(val_pred)
        _val_auc = roc_auc_score(val_true, val_pred, average='weighted')#something has to be fixed
        print('Validation AUC: {}'.format(_val_auc))
        self._val_auc.append(_val_auc)
        
        return

# %% [markdown]
# # Setup our Experiments

# %%
from keras.optimizers import Adam
import tensorflow as tf
def optimizerFactory():
    return Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, amsgrad=False)

# %%
import math
# learning rate schedule
def step_decay(epoch):
    initial_lrate = 0.0001
    drop = 0.5
    epochs_drop = 10.0
    lrate = initial_lrate * math.pow(drop,  
                math.floor((1+epoch)/epochs_drop))
    print('Lowering LR to {}'.format(lrate))
    return lrate

# %%
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
def getCheckpointCallback(name):
    return ModelCheckpoint(name, monitor='full_multi_label_metric', verbose=1, save_best_only=True, save_weights_only=False, mode='max', period=1)

# %%
#reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6, verbose=1)
#early_stopping = EarlyStopping(monitor='val_loss', min_delta=0, patience=15, verbose=0, mode='auto', baseline=None)

# %% [markdown]
# # Train images

# %%
#scheduled learning rate
lrate = LearningRateScheduler(step_decay)

# %%
params = {'dim': (224,224),
              'batch_size': 8,
              'n_channels': 1,
              'loc': image_loc,
              'shuffle': False,
              'modality': ['image'],
              'tokenizer':tokenizer,
               'mlb': mlb}
weightedAUCList = []
AUCList = []
for ix, split in data.items():
    K.clear_session()
    print('====================Starting Split Number {}===================='.format(ix))
    model = Generate_Model(model_type='image')#create model
    model.compile(optimizer=optimizerFactory(), loss='binary_crossentropy', metrics=[full_multi_label_metric])
    
    train_generator = padchestDataGenerator_DF(df.iloc[split['train']].reset_index(drop=True), **params)
    valid_generator = padchestDataGenerator_DF(df.iloc[split['valid']].reset_index(drop=True), **params)
    test_generator = padchestDataGenerator_DF(df.iloc[split['test']].reset_index(drop=True), **params)
    
    #checkpoint
    filename = 'imageOnly_{}_split_{}.hdf5'.format(projection,ix)
    checkpoint = getCheckpointCallback(filename)
    model.fit_generator(train_generator, steps_per_epoch=len(train_generator), validation_data=valid_generator, 
                        validation_steps=len(valid_generator), workers=workers, epochs=n_epochs, verbose=fitVerbose, class_weight=train_generator.labels_weights, 
                        callbacks=[checkpoint,lrate, AUC(valid_generator)])
    y_hat = model.predict_generator(test_generator, steps=len(test_generator), workers=workers)
    auc = roc_auc_score(test_generator.mlb.transform(df.iloc[split['test']].iloc[:len(y_hat)]['Final_Labels']), y_hat, average=None)
    AUCList.append(auc)
    weighted_auc = roc_auc_score(test_generator.mlb.transform(df.iloc[split['test']].iloc[:len(y_hat)]['Final_Labels']), y_hat, average='weighted')
    weightedAUCList.append(weighted_auc)
    print('Weighted AUC score for split {}: {}'.format(ix,weighted_auc))
AUC_Scores = pd.DataFrame({'Label': test_generator.mlb.classes_, 'Score': np.mean(AUCList, axis=0)}, columns=['Label', 'Score'])
AUC_Scores = AUC_Scores.append({'Label': 'weighted_auc', 'Score':np.mean(weightedAUCList, axis=0)}, ignore_index=True)#to csv    
AUC_Scores.to_csv('AUC_scores_imageOnly_{}'.format(projection))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0301 03:54:51.764790 47597341553536 deprecation_wrapper.py:119] From /gpfs/ysm/project/kl533/conda_envs/dlnn/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:95: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# W0301 03:54:51.766256 47597341553536 deprecation_wrapper.py:119] From /gpfs/ysm/project/kl533/conda_envs/dlnn/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:98: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0301 03:54:51.793039 47597341553536 deprecation_wrapper.py:119] From /gpfs/ysm/project/kl533/conda_envs/dlnn/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:102: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0301 03:54:51.794197 47597341553536 deprecation_wrapper.py:119] From /gpfs/ysm/project/kl533/conda_envs/dlnn/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0301 03:54:51.801361 47597341553536 deprecation_wrapper.py:119] From /gpfs/ysm/project/kl533/conda_envs/dlnn/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
# ====================Starting Split Number 0====================
# W0301 03:54:53.167625 47597341553536 deprecation_wrapper.py:119] From /gpfs/ysm/project/kl533/conda_envs/dlnn/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0301 03:54:53.225205 47597341553536 deprecation_wrapper.py:119] From /gpfs/ysm/project/kl533/conda_envs/dlnn/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0301 03:54:54.223280 47597341553536 deprecation_wrapper.py:119] From /gpfs/ysm/project/kl533/conda_envs/dlnn/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3980: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# W0301 03:55:09.474051 47597341553536 deprecation.py:506] From /gpfs/ysm/project/kl533/conda_envs/dlnn/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0301 03:55:09.592993 47597341553536 deprecation_wrapper.py:119] From /gpfs/ysm/project/kl533/conda_envs/dlnn/lib/python3.6/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0301 03:55:09.600471 47597341553536 deprecation.py:323] From /gpfs/ysm/project/kl533/conda_envs/dlnn/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Encoding Labels
# Encoding Labels
# Encoding Labels
# Lowering LR to 0.0001
#
# Epoch 00001: full_multi_label_metric improved from -inf to 0.00397, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.6122184192018193
# Lowering LR to 0.0001
#
# Epoch 00002: full_multi_label_metric improved from 0.00397 to 0.03419, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.6793105141616443
# Lowering LR to 0.0001
#
# Epoch 00003: full_multi_label_metric improved from 0.03419 to 0.10791, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.6909555535977735
# Lowering LR to 0.0001
#
# Epoch 00004: full_multi_label_metric improved from 0.10791 to 0.16361, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7247060295294036
# Lowering LR to 0.0001
#
# Epoch 00005: full_multi_label_metric improved from 0.16361 to 0.18391, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7231978892292426
# Lowering LR to 0.0001
#
# Epoch 00006: full_multi_label_metric improved from 0.18391 to 0.19658, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7387454038740757
# Lowering LR to 0.0001
#
# Epoch 00007: full_multi_label_metric improved from 0.19658 to 0.21368, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7369716786611752
# Lowering LR to 0.0001
#
# Epoch 00008: full_multi_label_metric improved from 0.21368 to 0.21459, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7380220513195725
# Lowering LR to 0.0001
#
# Epoch 00009: full_multi_label_metric improved from 0.21459 to 0.22512, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7424034373374824
# Lowering LR to 5e-05
#
# Epoch 00010: full_multi_label_metric improved from 0.22512 to 0.24313, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7603527704343253
# Lowering LR to 5e-05
#
# Epoch 00011: full_multi_label_metric improved from 0.24313 to 0.25748, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7701235755104489
# Lowering LR to 5e-05
#
# Epoch 00012: full_multi_label_metric improved from 0.25748 to 0.26190, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7574687650295854
# Lowering LR to 5e-05
#
# Epoch 00013: full_multi_label_metric improved from 0.26190 to 0.27396, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7668407960730818
# Lowering LR to 5e-05
#
# Epoch 00014: full_multi_label_metric improved from 0.27396 to 0.29090, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7580443376311701
# Lowering LR to 5e-05
#
# Epoch 00015: full_multi_label_metric improved from 0.29090 to 0.29686, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.758910984423534
# Lowering LR to 5e-05
#
# Epoch 00016: full_multi_label_metric improved from 0.29686 to 0.32799, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7430886949366626
# Lowering LR to 5e-05
#
# Epoch 00017: full_multi_label_metric improved from 0.32799 to 0.34493, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7512319030154543
# Lowering LR to 5e-05
#
# Epoch 00018: full_multi_label_metric improved from 0.34493 to 0.36615, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7573759883792488
# Lowering LR to 5e-05
#
# Epoch 00019: full_multi_label_metric improved from 0.36615 to 0.39209, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7450298744742739
# Lowering LR to 2.5e-05
#
# Epoch 00020: full_multi_label_metric improved from 0.39209 to 0.43681, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7326567834063815
# Lowering LR to 2.5e-05
#
# Epoch 00021: full_multi_label_metric improved from 0.43681 to 0.46749, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.733829731519555
# Lowering LR to 2.5e-05
#
# Epoch 00022: full_multi_label_metric improved from 0.46749 to 0.50183, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7492275484655663
# Lowering LR to 2.5e-05
#
# Epoch 00023: full_multi_label_metric improved from 0.50183 to 0.51145, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7442803156377147
# Lowering LR to 2.5e-05
#
# Epoch 00024: full_multi_label_metric improved from 0.51145 to 0.54197, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7498139617964324
# Lowering LR to 2.5e-05
#
# Epoch 00025: full_multi_label_metric improved from 0.54197 to 0.56090, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7396958223463392
# Lowering LR to 2.5e-05
#
# Epoch 00026: full_multi_label_metric improved from 0.56090 to 0.58364, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7462695601831291
# Lowering LR to 2.5e-05
#
# Epoch 00027: full_multi_label_metric improved from 0.58364 to 0.62607, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7332082526251475
# Lowering LR to 2.5e-05
#
# Epoch 00028: full_multi_label_metric improved from 0.62607 to 0.63858, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7366059866310622
# Lowering LR to 2.5e-05
#
# Epoch 00029: full_multi_label_metric improved from 0.63858 to 0.66606, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7343936050905214
# Lowering LR to 1.25e-05
#
# Epoch 00030: full_multi_label_metric improved from 0.66606 to 0.71184, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.73841679037707
# Lowering LR to 1.25e-05
#
# Epoch 00031: full_multi_label_metric improved from 0.71184 to 0.74786, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7374621876390645
# Lowering LR to 1.25e-05
#
# Epoch 00032: full_multi_label_metric improved from 0.74786 to 0.76221, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7360516675146173
# Lowering LR to 1.25e-05
#
# Epoch 00033: full_multi_label_metric improved from 0.76221 to 0.77320, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7413177159541783
# Lowering LR to 1.25e-05
#
# Epoch 00034: full_multi_label_metric improved from 0.77320 to 0.80067, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7330641058644294
# Lowering LR to 1.25e-05
#
# Epoch 00035: full_multi_label_metric improved from 0.80067 to 0.81502, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7335248650957533
# Lowering LR to 1.25e-05
#
# Epoch 00036: full_multi_label_metric improved from 0.81502 to 0.82372, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7329740876674585
# Lowering LR to 1.25e-05
#
# Epoch 00037: full_multi_label_metric improved from 0.82372 to 0.84158, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7324797603936637
# Lowering LR to 1.25e-05
#
# Epoch 00038: full_multi_label_metric improved from 0.84158 to 0.85424, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7322611685241318
# Lowering LR to 1.25e-05
#
# Epoch 00039: full_multi_label_metric improved from 0.85424 to 0.85745, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.72499096015341
# Lowering LR to 6.25e-06
#
# Epoch 00040: full_multi_label_metric improved from 0.85745 to 0.88141, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7374120860286926
# Lowering LR to 6.25e-06
#
# Epoch 00041: full_multi_label_metric improved from 0.88141 to 0.89530, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.733875779010415
# Lowering LR to 6.25e-06
#
# Epoch 00042: full_multi_label_metric improved from 0.89530 to 0.90354, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7359914604062908
# Lowering LR to 6.25e-06
#
# Epoch 00043: full_multi_label_metric improved from 0.90354 to 0.90522, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7326516301011654
# Lowering LR to 6.25e-06
#
# Epoch 00044: full_multi_label_metric improved from 0.90522 to 0.91071, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7331489627193455
# Lowering LR to 6.25e-06
#
# Epoch 00045: full_multi_label_metric improved from 0.91071 to 0.92231, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7332497681679369
# Lowering LR to 6.25e-06
#
# Epoch 00046: full_multi_label_metric did not improve from 0.92231
# Validation AUC: 0.7344904469997959
# Lowering LR to 6.25e-06
#
# Epoch 00047: full_multi_label_metric improved from 0.92231 to 0.92872, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7319961985753533
# Lowering LR to 6.25e-06
#
# Epoch 00048: full_multi_label_metric did not improve from 0.92872
# Validation AUC: 0.7291745769653081
# Lowering LR to 6.25e-06
#
# Epoch 00049: full_multi_label_metric improved from 0.92872 to 0.93193, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.73114125719751
# Lowering LR to 3.125e-06
#
# Epoch 00050: full_multi_label_metric improved from 0.93193 to 0.94093, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7330806420323518
# Lowering LR to 3.125e-06
#
# Epoch 00051: full_multi_label_metric improved from 0.94093 to 0.94673, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7316969261079723
# Lowering LR to 3.125e-06
#
# Epoch 00052: full_multi_label_metric did not improve from 0.94673
# Validation AUC: 0.7332557115330477
# Lowering LR to 3.125e-06
#
# Epoch 00053: full_multi_label_metric improved from 0.94673 to 0.95131, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.733083184298705
# Lowering LR to 3.125e-06
#
# Epoch 00054: full_multi_label_metric improved from 0.95131 to 0.95452, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7289199615233499
# Lowering LR to 3.125e-06
#
# Epoch 00055: full_multi_label_metric did not improve from 0.95452
# Validation AUC: 0.7334864269741054
# Lowering LR to 3.125e-06
#
# Epoch 00056: full_multi_label_metric did not improve from 0.95452
# Validation AUC: 0.7334077544314656
# Lowering LR to 3.125e-06
#
# Epoch 00057: full_multi_label_metric improved from 0.95452 to 0.95620, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7300624405887343
# Lowering LR to 3.125e-06
#
# Epoch 00058: full_multi_label_metric improved from 0.95620 to 0.95635, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7331866187971527
# Lowering LR to 3.125e-06
#
# Epoch 00059: full_multi_label_metric did not improve from 0.95635
# Validation AUC: 0.7316962247658771
# Lowering LR to 1.5625e-06
#
# Epoch 00060: full_multi_label_metric improved from 0.95635 to 0.95833, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.734321101142253
# Lowering LR to 1.5625e-06
#
# Epoch 00061: full_multi_label_metric improved from 0.95833 to 0.95894, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7318307612164888
# Lowering LR to 1.5625e-06
#
# Epoch 00062: full_multi_label_metric improved from 0.95894 to 0.96169, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7300256331912579
# Lowering LR to 1.5625e-06
#
# Epoch 00063: full_multi_label_metric did not improve from 0.96169
# Validation AUC: 0.7323206565688155
# Lowering LR to 1.5625e-06
#
# Epoch 00064: full_multi_label_metric improved from 0.96169 to 0.96261, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7338189556171494
# Lowering LR to 1.5625e-06
#
# Epoch 00065: full_multi_label_metric improved from 0.96261 to 0.96398, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7309333393045695
# Lowering LR to 1.5625e-06
#
# Epoch 00066: full_multi_label_metric improved from 0.96398 to 0.96581, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7308827588406875
# Lowering LR to 1.5625e-06
#
# Epoch 00067: full_multi_label_metric did not improve from 0.96581
# Validation AUC: 0.7304907893864678
# Lowering LR to 1.5625e-06
#
# Epoch 00068: full_multi_label_metric did not improve from 0.96581
# Validation AUC: 0.7325922948624082
# Lowering LR to 1.5625e-06
#
# Epoch 00069: full_multi_label_metric improved from 0.96581 to 0.96719, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7328805906074581
# Lowering LR to 7.8125e-07
#
# Epoch 00070: full_multi_label_metric did not improve from 0.96719
# Validation AUC: 0.732729099154162
# Lowering LR to 7.8125e-07
#
# Epoch 00071: full_multi_label_metric did not improve from 0.96719
# Validation AUC: 0.7332229300586413
# Lowering LR to 7.8125e-07
#
# Epoch 00072: full_multi_label_metric improved from 0.96719 to 0.96841, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7329671263515385
# Lowering LR to 7.8125e-07
#
# Epoch 00073: full_multi_label_metric improved from 0.96841 to 0.96856, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7323537409041313
# Lowering LR to 7.8125e-07
#
# Epoch 00074: full_multi_label_metric did not improve from 0.96856
# Validation AUC: 0.7330923656304666
# Lowering LR to 7.8125e-07
#
# Epoch 00075: full_multi_label_metric did not improve from 0.96856
# Validation AUC: 0.7323310853229564
# Lowering LR to 7.8125e-07
#
# Epoch 00076: full_multi_label_metric did not improve from 0.96856
# Validation AUC: 0.7328905462417051
# Lowering LR to 7.8125e-07
#
# Epoch 00077: full_multi_label_metric improved from 0.96856 to 0.96902, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7332971855338818
# Lowering LR to 7.8125e-07
#
# Epoch 00078: full_multi_label_metric did not improve from 0.96902
# Validation AUC: 0.7323982762676315
# Lowering LR to 7.8125e-07
#
# Epoch 00079: full_multi_label_metric improved from 0.96902 to 0.97176, saving model to imageOnly_PA_split_0.hdf5
# Validation AUC: 0.7329445152833114
# Lowering LR to 3.90625e-07
#
# Epoch 00080: full_multi_label_metric did not improve from 0.97176
# Validation AUC: 0.7332720265195986
# Weighted AUC score for split 0: 0.7373529337519468

# %%
'''for key in sorted(train_generator.labels_count):
    print('{}:{}'.format(key,train_generator.labels_count[key]))
print(len(train_generator.labels_count))
print('====================================')
for key in sorted(valid_generator.labels_count):
    print('{}:{}'.format(key,valid_generator.labels_count[key]))
print(len(valid_generator.labels_count))
print('====================================')
for key in sorted(test_generator.labels_count):
    print('{}:{}'.format(key,test_generator.labels_count[key]))
print(len(test_generator.labels_count))'''
# Out:
# "for key in sorted(train_generator.labels_count):\n    print('{}:{}'.format(key,train_generator.labels_count[key]))\nprint(len(train_generator.labels_count))\nprint('====================================')\nfor key in sorted(valid_generator.labels_count):\n    print('{}:{}'.format(key,valid_generator.labels_count[key]))\nprint(len(valid_generator.labels_count))\nprint('====================================')\nfor key in sorted(test_generator.labels_count):\n    print('{}:{}'.format(key,test_generator.labels_count[key]))\nprint(len(test_generator.labels_count))"

# %% [markdown]
# ## Text only

# %%
params = {'dim': (224,224),
              'batch_size': 8,
              'n_channels': 1,
              'loc': image_loc,
              'shuffle': False,
              'modality': ['text'],
              'tokenizer':tokenizer,
               'mlb': mlb}
weightedAUCList = []
AUCList = []
for ix, split in data.items():
    K.clear_session()
    print('====================Starting Split Number {}===================='.format(ix))
    model = Generate_Model(model_type='text_1d')#create model
    model.compile(optimizer=optimizerFactory(), loss='binary_crossentropy', metrics=[full_multi_label_metric])
    
    train_generator = padchestDataGenerator_DF(df.iloc[split['train']].reset_index(drop=True), **params)
    valid_generator = padchestDataGenerator_DF(df.iloc[split['valid']].reset_index(drop=True), **params)
    test_generator = padchestDataGenerator_DF(df.iloc[split['test']].reset_index(drop=True), **params)
    #checkpoint
    filename = 'textOnly_{}_split_{}.hdf5'.format(projection,ix)
    checkpoint = getCheckpointCallback(filename)
    model.fit_generator(train_generator, steps_per_epoch=len(train_generator), validation_data=valid_generator, 
                        validation_steps=len(valid_generator), workers=workers, epochs=n_epochs, verbose=fitVerbose, class_weight=train_generator.labels_weights, 
                        callbacks=[checkpoint,lrate, AUC(valid_generator)])
    y_hat = model.predict_generator(test_generator, steps=len(test_generator), workers=workers)
    auc = roc_auc_score(test_generator.mlb.transform(df.iloc[split['test']].iloc[:len(y_hat)]['Final_Labels']), y_hat, average=None)
    AUCList.append(auc)
    weighted_auc = roc_auc_score(test_generator.mlb.transform(df.iloc[split['test']].iloc[:len(y_hat)]['Final_Labels']), y_hat, average='weighted')
    weightedAUCList.append(weighted_auc)
    print('Weighted AUC score for split {}: {}'.format(ix,weighted_auc))
AUC_Scores = pd.DataFrame({'Label': test_generator.mlb.classes_, 'Score': np.mean(AUCList, axis=0)}, columns=['Label', 'Score'])
AUC_Scores = AUC_Scores.append({'Label': 'weighted_auc', 'Score':np.mean(weightedAUCList, axis=0)}, ignore_index=True)#to csv    
AUC_Scores.to_csv('AUC_scores_textOnly_{}'.format(projection))
# Out:
# ====================Starting Split Number 0====================
# Encoding Labels
# You have passed in a tokenizer, we will just convert to sequences
# filtering sentences
# filtering sents and removing stopwords
# Encoding Labels
# You have passed in a tokenizer, we will just convert to sequences
# filtering sentences
# filtering sents and removing stopwords
# Encoding Labels
# You have passed in a tokenizer, we will just convert to sequences
# filtering sentences
# filtering sents and removing stopwords
# Lowering LR to 0.0001
#
# Epoch 00001: full_multi_label_metric improved from -inf to 0.00977, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.7759700067964073
# Lowering LR to 0.0001
#
# Epoch 00002: full_multi_label_metric improved from 0.00977 to 0.08471, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.7988968798830886
# Lowering LR to 0.0001
#
# Epoch 00003: full_multi_label_metric improved from 0.08471 to 0.24100, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.8318469922640525
# Lowering LR to 0.0001
#
# Epoch 00004: full_multi_label_metric improved from 0.24100 to 0.32647, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.837703470517877
# Lowering LR to 0.0001
#
# Epoch 00005: full_multi_label_metric improved from 0.32647 to 0.35226, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.8684439349031363
# Lowering LR to 0.0001
#
# Epoch 00006: full_multi_label_metric improved from 0.35226 to 0.37439, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.8822740439378701
# Lowering LR to 0.0001
#
# Epoch 00007: full_multi_label_metric improved from 0.37439 to 0.38233, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.8952081049173524
# Lowering LR to 0.0001
#
# Epoch 00008: full_multi_label_metric improved from 0.38233 to 0.39927, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.9027218664719805
# Lowering LR to 0.0001
#
# Epoch 00009: full_multi_label_metric improved from 0.39927 to 0.41239, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.9169977011054691
# Lowering LR to 5e-05
#
# Epoch 00010: full_multi_label_metric improved from 0.41239 to 0.43132, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.9209968536437728
# Lowering LR to 5e-05
#
# Epoch 00011: full_multi_label_metric did not improve from 0.43132
# Validation AUC: 0.9230599541491626
# Lowering LR to 5e-05
#
# Epoch 00012: full_multi_label_metric improved from 0.43132 to 0.44704, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.9294407140105334
# Lowering LR to 5e-05
#
# Epoch 00013: full_multi_label_metric improved from 0.44704 to 0.44872, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.9333954086302519
# Lowering LR to 5e-05
#
# Epoch 00014: full_multi_label_metric improved from 0.44872 to 0.46551, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.9354338591595599
# Lowering LR to 5e-05
#
# Epoch 00015: full_multi_label_metric improved from 0.46551 to 0.47176, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.9378878437719257
# Lowering LR to 5e-05
#
# Epoch 00016: full_multi_label_metric improved from 0.47176 to 0.47283, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.9391430308969632
# Lowering LR to 5e-05
#
# Epoch 00017: full_multi_label_metric improved from 0.47283 to 0.48214, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.9409526749510293
# Lowering LR to 5e-05
#
# Epoch 00018: full_multi_label_metric improved from 0.48214 to 0.49512, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.9426768645505812
# Lowering LR to 5e-05
#
# Epoch 00019: full_multi_label_metric improved from 0.49512 to 0.50397, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.9440309699964633
# Lowering LR to 2.5e-05
#
# Epoch 00020: full_multi_label_metric improved from 0.50397 to 0.50580, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.9454560767752062
# Lowering LR to 2.5e-05
#
# Epoch 00021: full_multi_label_metric improved from 0.50580 to 0.50809, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.9468126515830715
# Lowering LR to 2.5e-05
#
# Epoch 00022: full_multi_label_metric improved from 0.50809 to 0.51297, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.9477385892609825
# Lowering LR to 2.5e-05
#
# Epoch 00023: full_multi_label_metric improved from 0.51297 to 0.51984, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.9482080626733622
# Lowering LR to 2.5e-05
#
# Epoch 00024: full_multi_label_metric did not improve from 0.51984
# Validation AUC: 0.9483205080516154
# Lowering LR to 2.5e-05
#
# Epoch 00025: full_multi_label_metric improved from 0.51984 to 0.52457, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.9480695021115269
# Lowering LR to 2.5e-05
#
# Epoch 00026: full_multi_label_metric improved from 0.52457 to 0.53266, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.9495882174216452
# Lowering LR to 2.5e-05
#
# Epoch 00027: full_multi_label_metric did not improve from 0.53266
# Validation AUC: 0.9502735773400399
# Lowering LR to 2.5e-05
#
# Epoch 00028: full_multi_label_metric did not improve from 0.53266
# Validation AUC: 0.9503341005755542
# Lowering LR to 2.5e-05
#
# Epoch 00029: full_multi_label_metric improved from 0.53266 to 0.53342, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.9513047083772109
# Lowering LR to 1.25e-05
#
# Epoch 00030: full_multi_label_metric did not improve from 0.53342
# Validation AUC: 0.9502737510708756
# Lowering LR to 1.25e-05
#
# Epoch 00031: full_multi_label_metric improved from 0.53342 to 0.53678, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.9520281639935825
# Lowering LR to 1.25e-05
#
# Epoch 00032: full_multi_label_metric improved from 0.53678 to 0.54106, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.9513486013147707
# Lowering LR to 1.25e-05
#
# Epoch 00033: full_multi_label_metric improved from 0.54106 to 0.54121, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.9525713785012859
# Lowering LR to 1.25e-05
#
# Epoch 00034: full_multi_label_metric did not improve from 0.54121
# Validation AUC: 0.9523437229259257
# Lowering LR to 1.25e-05
#
# Epoch 00035: full_multi_label_metric improved from 0.54121 to 0.54426, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.953622862880507
# Lowering LR to 1.25e-05
#
# Epoch 00036: full_multi_label_metric improved from 0.54426 to 0.55098, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.9536176847061654
# Lowering LR to 1.25e-05
#
# Epoch 00037: full_multi_label_metric did not improve from 0.55098
# Validation AUC: 0.9534530089165714
# Lowering LR to 1.25e-05
#
# Epoch 00038: full_multi_label_metric did not improve from 0.55098
# Validation AUC: 0.9544538438098819
# Lowering LR to 1.25e-05
#
# Epoch 00039: full_multi_label_metric did not improve from 0.55098
# Validation AUC: 0.9551097590167048
# Lowering LR to 6.25e-06
#
# Epoch 00040: full_multi_label_metric did not improve from 0.55098
# Validation AUC: 0.9550640498065318
# Lowering LR to 6.25e-06
#
# Epoch 00041: full_multi_label_metric improved from 0.55098 to 0.55388, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.9550308719249955
# Lowering LR to 6.25e-06
#
# Epoch 00042: full_multi_label_metric did not improve from 0.55388
# Validation AUC: 0.9551579643933047
# Lowering LR to 6.25e-06
#
# Epoch 00043: full_multi_label_metric did not improve from 0.55388
# Validation AUC: 0.9552108223739773
# Lowering LR to 6.25e-06
#
# Epoch 00044: full_multi_label_metric did not improve from 0.55388
# Validation AUC: 0.9558445339014345
# Lowering LR to 6.25e-06
#
# Epoch 00045: full_multi_label_metric did not improve from 0.55388
# Validation AUC: 0.9556537135233927
# Lowering LR to 6.25e-06
#
# Epoch 00046: full_multi_label_metric did not improve from 0.55388
# Validation AUC: 0.9557530873918015
# Lowering LR to 6.25e-06
#
# Epoch 00047: full_multi_label_metric did not improve from 0.55388
# Validation AUC: 0.9555014573296066
# Lowering LR to 6.25e-06
#
# Epoch 00048: full_multi_label_metric did not improve from 0.55388
# Validation AUC: 0.9555908366530405
# Lowering LR to 6.25e-06
#
# Epoch 00049: full_multi_label_metric improved from 0.55388 to 0.55693, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.9554080583878821
# Lowering LR to 3.125e-06
#
# Epoch 00050: full_multi_label_metric did not improve from 0.55693
# Validation AUC: 0.9558080249568028
# Lowering LR to 3.125e-06
#
# Epoch 00051: full_multi_label_metric did not improve from 0.55693
# Validation AUC: 0.956426480984227
# Lowering LR to 3.125e-06
#
# Epoch 00052: full_multi_label_metric improved from 0.55693 to 0.55907, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.956184292776006
# Lowering LR to 3.125e-06
#
# Epoch 00053: full_multi_label_metric did not improve from 0.55907
# Validation AUC: 0.9557435684314097
# Lowering LR to 3.125e-06
#
# Epoch 00054: full_multi_label_metric improved from 0.55907 to 0.55983, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.956087693326188
# Lowering LR to 3.125e-06
#
# Epoch 00055: full_multi_label_metric did not improve from 0.55983
# Validation AUC: 0.9561170293247723
# Lowering LR to 3.125e-06
#
# Epoch 00056: full_multi_label_metric improved from 0.55983 to 0.56013, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.9563078095887498
# Lowering LR to 3.125e-06
#
# Epoch 00057: full_multi_label_metric improved from 0.56013 to 0.56090, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.9560815640623037
# Lowering LR to 3.125e-06
#
# Epoch 00058: full_multi_label_metric did not improve from 0.56090
# Validation AUC: 0.956383212515499
# Lowering LR to 3.125e-06
#
# Epoch 00059: full_multi_label_metric did not improve from 0.56090
# Validation AUC: 0.957153463934099
# Lowering LR to 1.5625e-06
#
# Epoch 00060: full_multi_label_metric did not improve from 0.56090
# Validation AUC: 0.9565462846564072
# Lowering LR to 1.5625e-06
#
# Epoch 00061: full_multi_label_metric did not improve from 0.56090
# Validation AUC: 0.9567644606054907
# Lowering LR to 1.5625e-06
#
# Epoch 00062: full_multi_label_metric improved from 0.56090 to 0.56319, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.9567777292173683
# Lowering LR to 1.5625e-06
#
# Epoch 00063: full_multi_label_metric did not improve from 0.56319
# Validation AUC: 0.9562340506352227
# Lowering LR to 1.5625e-06
#
# Epoch 00064: full_multi_label_metric did not improve from 0.56319
# Validation AUC: 0.9570052211705404
# Lowering LR to 1.5625e-06
#
# Epoch 00065: full_multi_label_metric improved from 0.56319 to 0.56502, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.9571275144646552
# Lowering LR to 1.5625e-06
#
# Epoch 00066: full_multi_label_metric did not improve from 0.56502
# Validation AUC: 0.9568010929791062
# Lowering LR to 1.5625e-06
#
# Epoch 00067: full_multi_label_metric improved from 0.56502 to 0.56929, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.956894660966658
# Lowering LR to 1.5625e-06
#
# Epoch 00068: full_multi_label_metric did not improve from 0.56929
# Validation AUC: 0.9572847102825207
# Lowering LR to 1.5625e-06
#
# Epoch 00069: full_multi_label_metric did not improve from 0.56929
# Validation AUC: 0.9574134015798336
# Lowering LR to 7.8125e-07
#
# Epoch 00070: full_multi_label_metric improved from 0.56929 to 0.57158, saving model to textOnly_PA_split_0.hdf5
# Validation AUC: 0.9572754182017281
# Lowering LR to 7.8125e-07
#
# Epoch 00071: full_multi_label_metric did not improve from 0.57158
# Validation AUC: 0.9571155861559573
# Lowering LR to 7.8125e-07
#
# Epoch 00072: full_multi_label_metric did not improve from 0.57158
# Validation AUC: 0.9570227862690759
# Lowering LR to 7.8125e-07
#
# Epoch 00073: full_multi_label_metric did not improve from 0.57158
# Validation AUC: 0.9565801232333477
# Lowering LR to 7.8125e-07
#
# Epoch 00074: full_multi_label_metric did not improve from 0.57158
# Validation AUC: 0.9570624581937536
# Lowering LR to 7.8125e-07
#
# Epoch 00075: full_multi_label_metric did not improve from 0.57158
# Validation AUC: 0.9573122503317187
# Lowering LR to 7.8125e-07
#
# Epoch 00076: full_multi_label_metric did not improve from 0.57158
# Validation AUC: 0.9569455821759585
# Lowering LR to 7.8125e-07
#
# Epoch 00077: full_multi_label_metric did not improve from 0.57158
# Validation AUC: 0.9572791547892588
# Lowering LR to 7.8125e-07
#
# Epoch 00078: full_multi_label_metric did not improve from 0.57158
# Validation AUC: 0.9571367935240103
# Lowering LR to 7.8125e-07
#
# Epoch 00079: full_multi_label_metric did not improve from 0.57158
# Validation AUC: 0.9568206374819362
# Lowering LR to 3.90625e-07
#
# Epoch 00080: full_multi_label_metric did not improve from 0.57158
# Validation AUC: 0.9567694028735335
# Weighted AUC score for split 0: 0.9620166410158828

# %% [markdown]
# # Train multimodal Models

# %%
params = {'dim': (224,224),
              'batch_size': 8,
              'n_channels': 1,
              'loc': '/gpfs/ysm/home/kl533/krauthammer_partition/padchest_2019_small/images-224/',
              'shuffle': False,
              'modality': ['image', 'text'],
              'tokenizer':tokenizer,
               'mlb': mlb}

# %% [markdown]
# ## Model Fusion Randomly Initialized

# %%
weightedAUCList = []
AUCList = []
for ix, split in data.items():
    K.clear_session()
    print('====================Starting Split Number {}===================='.format(ix))
    model = Generate_Model(model_type='ModelFusion')#create model
    model.compile(optimizer=optimizerFactory(), loss='binary_crossentropy', metrics=[full_multi_label_metric])
    
    train_generator = padchestDataGenerator_DF(df.iloc[split['train']].reset_index(drop=True), **params)
    valid_generator = padchestDataGenerator_DF(df.iloc[split['valid']].reset_index(drop=True), **params)
    test_generator = padchestDataGenerator_DF(df.iloc[split['test']].reset_index(drop=True), **params)
    #checkpoint
    filename = 'modelFusion_{}_split_{}.hdf5'.format(projection,ix)#'imageOnly_lat.hdf5'
    checkpoint = getCheckpointCallback(filename)
    model.fit_generator(train_generator, steps_per_epoch=len(train_generator), validation_data=valid_generator, 
                        validation_steps=len(valid_generator), workers=workers, epochs=n_epochs, verbose=fitVerbose, class_weight=train_generator.labels_weights, 
                        callbacks=[checkpoint,lrate, AUC(valid_generator)])
    y_hat = model.predict_generator(test_generator, steps=len(test_generator), workers=workers)
    auc = roc_auc_score(test_generator.mlb.transform(df.iloc[split['test']].iloc[:len(y_hat)]['Final_Labels']), y_hat, average=None)
    AUCList.append(auc)
    weighted_auc = roc_auc_score(test_generator.mlb.transform(df.iloc[split['test']].iloc[:len(y_hat)]['Final_Labels']), y_hat, average='weighted')
    weightedAUCList.append(weighted_auc)
    print('Weighted AUC score for split {}: {}'.format(ix,weighted_auc))
AUC_Scores = pd.DataFrame({'Label': test_generator.mlb.classes_, 'Score': np.mean(AUCList, axis=0)}, columns=['Label', 'Score'])
AUC_Scores = AUC_Scores.append({'Label': 'weighted_auc', 'Score':np.mean(weightedAUCList, axis=0)}, ignore_index=True)#to csv    
AUC_Scores.to_csv('AUC_scores_ModelFusion_{}'.format(projection))
# Out:
# ====================Starting Split Number 0====================
# Encoding Labels
# You have passed in a tokenizer, we will just convert to sequences
# filtering sentences
# filtering sents and removing stopwords
# Encoding Labels
# You have passed in a tokenizer, we will just convert to sequences
# filtering sentences
# filtering sents and removing stopwords
# Encoding Labels
# You have passed in a tokenizer, we will just convert to sequences
# filtering sentences
# filtering sents and removing stopwords
# Lowering LR to 0.0001
#
# Epoch 00001: full_multi_label_metric improved from -inf to 0.00733, saving model to modelFusion_PA_split_0.hdf5
# Validation AUC: 0.7752638695777186
# Lowering LR to 0.0001
#
# Epoch 00002: full_multi_label_metric improved from 0.00733 to 0.07845, saving model to modelFusion_PA_split_0.hdf5
# Validation AUC: 0.8124004521313167
# Lowering LR to 0.0001
#
# Epoch 00003: full_multi_label_metric improved from 0.07845 to 0.23230, saving model to modelFusion_PA_split_0.hdf5
# Validation AUC: 0.8658039340723366
# Lowering LR to 0.0001
#
# Epoch 00004: full_multi_label_metric improved from 0.23230 to 0.33578, saving model to modelFusion_PA_split_0.hdf5
# Validation AUC: 0.8931046397383334
# Lowering LR to 0.0001
#
# Epoch 00005: full_multi_label_metric improved from 0.33578 to 0.38446, saving model to modelFusion_PA_split_0.hdf5
# Validation AUC: 0.9097772640288394
# Lowering LR to 0.0001
#
# Epoch 00006: full_multi_label_metric improved from 0.38446 to 0.40842, saving model to modelFusion_PA_split_0.hdf5
# Validation AUC: 0.9126348659383275
# Lowering LR to 0.0001
#
# Epoch 00007: full_multi_label_metric improved from 0.40842 to 0.42933, saving model to modelFusion_PA_split_0.hdf5
# Validation AUC: 0.9287788422399975
# Lowering LR to 0.0001
#
# Epoch 00008: full_multi_label_metric improved from 0.42933 to 0.44918, saving model to modelFusion_PA_split_0.hdf5
# Validation AUC: 0.9323852110618994
# Lowering LR to 0.0001
#
# Epoch 00009: full_multi_label_metric improved from 0.44918 to 0.46642, saving model to modelFusion_PA_split_0.hdf5
# Validation AUC: 0.9411277686135627
# Lowering LR to 5e-05
#
# Epoch 00010: full_multi_label_metric improved from 0.46642 to 0.48611, saving model to modelFusion_PA_split_0.hdf5
# Validation AUC: 0.947164276057501
# Lowering LR to 5e-05
#
# Epoch 00011: full_multi_label_metric improved from 0.48611 to 0.49847, saving model to modelFusion_PA_split_0.hdf5
# Validation AUC: 0.9493125206151509
# Lowering LR to 5e-05
#
# Epoch 00012: full_multi_label_metric improved from 0.49847 to 0.51038, saving model to modelFusion_PA_split_0.hdf5
# Validation AUC: 0.9508850276509219
# Lowering LR to 5e-05
#
# Epoch 00013: full_multi_label_metric improved from 0.51038 to 0.51358, saving model to modelFusion_PA_split_0.hdf5
# Validation AUC: 0.9532374687140485
# Lowering LR to 5e-05
#
# Epoch 00014: full_multi_label_metric improved from 0.51358 to 0.52198, saving model to modelFusion_PA_split_0.hdf5
# Validation AUC: 0.9537078012882917
# Lowering LR to 5e-05
#
# Epoch 00015: full_multi_label_metric improved from 0.52198 to 0.53388, saving model to modelFusion_PA_split_0.hdf5
# Validation AUC: 0.9546990280348397
# Lowering LR to 5e-05
#
# Epoch 00016: full_multi_label_metric improved from 0.53388 to 0.54533, saving model to modelFusion_PA_split_0.hdf5
# Validation AUC: 0.957399260718976
# Lowering LR to 5e-05
#
# Epoch 00017: full_multi_label_metric improved from 0.54533 to 0.55143, saving model to modelFusion_PA_split_0.hdf5
# Validation AUC: 0.9551998304117088
# Lowering LR to 5e-05
#
# Epoch 00018: full_multi_label_metric improved from 0.55143 to 0.56487, saving model to modelFusion_PA_split_0.hdf5
# Validation AUC: 0.9584045983021113
# Lowering LR to 5e-05
#
# Epoch 00019: full_multi_label_metric improved from 0.56487 to 0.57005, saving model to modelFusion_PA_split_0.hdf5
# Validation AUC: 0.9590390863344243
# Lowering LR to 2.5e-05
#
# Epoch 00020: full_multi_label_metric improved from 0.57005 to 0.59127, saving model to modelFusion_PA_split_0.hdf5
# Validation AUC: 0.9593773916869408
# Lowering LR to 2.5e-05
#
# Epoch 00021: full_multi_label_metric improved from 0.59127 to 0.60195, saving model to modelFusion_PA_split_0.hdf5
# Validation AUC: 0.9582664693681763
# Lowering LR to 2.5e-05
#
# Epoch 00022: full_multi_label_metric improved from 0.60195 to 0.61462, saving model to modelFusion_PA_split_0.hdf5
# Validation AUC: 0.9589726155958606
# Lowering LR to 2.5e-05
#
# Epoch 00023: full_multi_label_metric improved from 0.61462 to 0.62531, saving model to modelFusion_PA_split_0.hdf5
# Validation AUC: 0.9590301654304765
# Lowering LR to 2.5e-05
#
# Epoch 00024: full_multi_label_metric improved from 0.62531 to 0.64347, saving model to modelFusion_PA_split_0.hdf5
# Validation AUC: 0.9587305946810111
# Lowering LR to 2.5e-05
#
# Epoch 00025: full_multi_label_metric improved from 0.64347 to 0.65339, saving model to modelFusion_PA_split_0.hdf5
# Validation AUC: 0.9585871128193447
# Lowering LR to 2.5e-05
#
# Epoch 00026: full_multi_label_metric improved from 0.65339 to 0.67750, saving model to modelFusion_PA_split_0.hdf5
# Validation AUC: 0.9571758110309585
# Lowering LR to 2.5e-05
#
# Epoch 00027: full_multi_label_metric improved from 0.67750 to 0.68788, saving model to modelFusion_PA_split_0.hdf5
# Validation AUC: 0.9573757949645136
# Lowering LR to 2.5e-05
#
# Epoch 00028: full_multi_label_metric improved from 0.68788 to 0.71047, saving model to modelFusion_PA_split_0.hdf5
# Validation AUC: 0.9553383770063296
# Lowering LR to 2.5e-05
#
# Epoch 00029: full_multi_label_metric improved from 0.71047 to 0.72436, saving model to modelFusion_PA_split_0.hdf5
# Validation AUC: 0.9566609228870677
# Lowering LR to 1.25e-05
#
# Epoch 00030: full_multi_label_metric improved from 0
    model.compile(optimizer=optimizerFactory(), loss='binary_crossentropy', metrics=[full_multi_label_metric])
    
    train_generator = padchestDataGenerator_DF(df.iloc[split['train']].reset_index(drop=True), **params)
    valid_generator = padchestDataGenerator_DF(df.iloc[split['valid']].reset_index(drop=True), **params)
    test_generator = padchestDataGenerator_DF(df.iloc[split['test']].reset_index(drop=True), **params)
    #checkpoint
    filename = 'modelFusion_PT_{}_split_{}.hdf5'.format(projection,ix)
    checkpoint = getCheckpointCallback(filename)
    
    #Load weights
    model.layers[2].set_weights(load_model('imageOnly_{}_split_{}.hdf5'.format(projection,ix),compile=False).layers[1].get_weights())#image
    model.layers[5].set_weights(load_model('textOnly_{}_split_{}.hdf5'.format(projection,ix),compile=False).layers[2].get_weights())#text
    
    #Fit Model
    model.fit_generator(train_generator, steps_per_epoch=len(train_generator), validation_data=valid_generator, 
                        validation_steps=len(valid_generator), workers=workers, epochs=n_epochs, verbose=fitVerbose, class_weight=train_generator.labels_weights, 
                        callbacks=[checkpoint,lrate, AUC(valid_generator)])
    y_hat = model.predict_generator(test_generator, steps=len(test_generator), workers=workers)
    auc = roc_auc_score(test_generator.mlb.transform(df.iloc[split['test']].iloc[:len(y_hat)]['Final_Labels']), y_hat, average=None)
    AUCList.append(auc)
    weighted_auc = roc_auc_score(test_generator.mlb.transform(df.iloc[split['test']].iloc[:len(y_hat)]['Final_Labels']), y_hat, average='weighted')
    weightedAUCList.append(weighted_auc)
    print('Weighted AUC score for split {}: {}'.format(ix,weighted_auc))
AUC_Scores = pd.DataFrame({'Label': test_generator.mlb.classes_, 'Score': np.mean(AUCList, axis=0)}, columns=['Label', 'Score'])
AUC_Scores = AUC_Scores.append({'Label': 'weighted_auc', 'Score':np.mean(weightedAUCList, axis=0)}, ignore_index=True)#to csv    
AUC_Scores.to_csv('AUC_scores_ModelFusion_PT_{}'.format(projection))
# Out:
# ====================Starting Split Number 0====================
# Encoding Labels
# You have passed in a tokenizer, we will just convert to sequences
# filtering sentences
# filtering sents and removing stopwords
# Encoding Labels
# You have passed in a tokenizer, we will just convert to sequences
# filtering sentences
# filtering sents and removing stopwords
# Encoding Labels
# You have passed in a tokenizer, we will just convert to sequences
# filtering sentences
# filtering sents and removing stopwords
# Lowering LR to 0.0001
#
# Epoch 00001: full_multi_label_metric improved from -inf to 0.01389, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.890046140056836
# Lowering LR to 0.0001
#
# Epoch 00002: full_multi_label_metric improved from 0.01389 to 0.10821, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9269861768123374
# Lowering LR to 0.0001
#
# Epoch 00003: full_multi_label_metric improved from 0.10821 to 0.29594, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9395924202255602
# Lowering LR to 0.0001
#
# Epoch 00004: full_multi_label_metric improved from 0.29594 to 0.41621, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.94198265802782
# Lowering LR to 0.0001
#
# Epoch 00005: full_multi_label_metric improved from 0.41621 to 0.45940, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9494999408032851
# Lowering LR to 0.0001
#
# Epoch 00006: full_multi_label_metric improved from 0.45940 to 0.48840, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9527076759556561
# Lowering LR to 0.0001
#
# Epoch 00007: full_multi_label_metric improved from 0.48840 to 0.49969, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9596340711456431
# Lowering LR to 0.0001
#
# Epoch 00008: full_multi_label_metric improved from 0.49969 to 0.52259, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.962717193275056
# Lowering LR to 0.0001
#
# Epoch 00009: full_multi_label_metric improved from 0.52259 to 0.53495, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9624883043900896
# Lowering LR to 5e-05
#
# Epoch 00010: full_multi_label_metric improved from 0.53495 to 0.56410, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.966504712591027
# Lowering LR to 5e-05
#
# Epoch 00011: full_multi_label_metric improved from 0.56410 to 0.57448, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9686455580603698
# Lowering LR to 5e-05
#
# Epoch 00012: full_multi_label_metric improved from 0.57448 to 0.59539, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9672705279481519
# Lowering LR to 5e-05
#
# Epoch 00013: full_multi_label_metric did not improve from 0.59539
# Validation AUC: 0.9681308092747174
# Lowering LR to 5e-05
#
# Epoch 00014: full_multi_label_metric improved from 0.59539 to 0.60745, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9694643981042786
# Lowering LR to 5e-05
#
# Epoch 00015: full_multi_label_metric improved from 0.60745 to 0.61615, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9696251541918202
# Lowering LR to 5e-05
#
# Epoch 00016: full_multi_label_metric improved from 0.61615 to 0.63431, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9682604717197789
# Lowering LR to 5e-05
#
# Epoch 00017: full_multi_label_metric improved from 0.63431 to 0.64301, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.970398616963042
# Lowering LR to 5e-05
#
# Epoch 00018: full_multi_label_metric improved from 0.64301 to 0.66880, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.969332828523358
# Lowering LR to 5e-05
#
# Epoch 00019: full_multi_label_metric improved from 0.66880 to 0.68483, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9693215694529828
# Lowering LR to 2.5e-05
#
# Epoch 00020: full_multi_label_metric improved from 0.68483 to 0.70864, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9712508104124856
# Lowering LR to 2.5e-05
#
# Epoch 00021: full_multi_label_metric improved from 0.70864 to 0.73184, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9687470432665991
# Lowering LR to 2.5e-05
#
# Epoch 00022: full_multi_label_metric improved from 0.73184 to 0.75565, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9678139612570357
# Lowering LR to 2.5e-05
#
# Epoch 00023: full_multi_label_metric improved from 0.75565 to 0.77549, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9693468301748567
# Lowering LR to 2.5e-05
#
# Epoch 00024: full_multi_label_metric improved from 0.77549 to 0.78861, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9681480507716869
# Lowering LR to 2.5e-05
#
# Epoch 00025: full_multi_label_metric improved from 0.78861 to 0.80998, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.969268692701639
# Lowering LR to 2.5e-05
#
# Epoch 00026: full_multi_label_metric improved from 0.80998 to 0.82692, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9676558244398997
# Lowering LR to 2.5e-05
#
# Epoch 00027: full_multi_label_metric improved from 0.82692 to 0.84234, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9684398435057995
# Lowering LR to 2.5e-05
#
# Epoch 00028: full_multi_label_metric improved from 0.84234 to 0.84875, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.967905817284226
# Lowering LR to 2.5e-05
#
# Epoch 00029: full_multi_label_metric improved from 0.84875 to 0.86325, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9680138225863887
# Lowering LR to 1.25e-05
#
# Epoch 00030: full_multi_label_metric improved from 0.86325 to 0.87882, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9673005359861109
# Lowering LR to 1.25e-05
#
# Epoch 00031: full_multi_label_metric improved from 0.87882 to 0.89591, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9663725260872864
# Lowering LR to 1.25e-05
#
# Epoch 00032: full_multi_label_metric improved from 0.89591 to 0.90171, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9669353937953755
# Lowering LR to 1.25e-05
#
# Epoch 00033: full_multi_label_metric improved from 0.90171 to 0.90980, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9662310341538725
# Lowering LR to 1.25e-05
#
# Epoch 00034: full_multi_label_metric improved from 0.90980 to 0.91194, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9650177548147569
# Lowering LR to 1.25e-05
#
# Epoch 00035: full_multi_label_metric improved from 0.91194 to 0.92552, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9646767479519638
# Lowering LR to 1.25e-05
#
# Epoch 00036: full_multi_label_metric did not improve from 0.92552
# Validation AUC: 0.9656151615933112
# Lowering LR to 1.25e-05
#
# Epoch 00037: full_multi_label_metric improved from 0.92552 to 0.92613, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9655193897934113
# Lowering LR to 1.25e-05
#
# Epoch 00038: full_multi_label_metric improved from 0.92613 to 0.92872, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9653917422998914
# Lowering LR to 1.25e-05
#
# Epoch 00039: full_multi_label_metric did not improve from 0.92872
# Validation AUC: 0.9654319917937768
# Lowering LR to 6.25e-06
#
# Epoch 00040: full_multi_label_metric improved from 0.92872 to 0.94017, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9645910977919216
# Lowering LR to 6.25e-06
#
# Epoch 00041: full_multi_label_metric improved from 0.94017 to 0.94292, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9649666445671746
# Lowering LR to 6.25e-06
#
# Epoch 00042: full_multi_label_metric improved from 0.94292 to 0.94521, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9649614351650394
# Lowering LR to 6.25e-06
#
# Epoch 00043: full_multi_label_metric improved from 0.94521 to 0.95040, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9651593664366543
# Lowering LR to 6.25e-06
#
# Epoch 00044: full_multi_label_metric improved from 0.95040 to 0.95284, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9646113225904218
# Lowering LR to 6.25e-06
#
# Epoch 00045: full_multi_label_metric improved from 0.95284 to 0.95467, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.964423280708825
# Lowering LR to 6.25e-06
#
# Epoch 00046: full_multi_label_metric did not improve from 0.95467
# Validation AUC: 0.9643102512778229
# Lowering LR to 6.25e-06
#
# Epoch 00047: full_multi_label_metric did not improve from 0.95467
# Validation AUC: 0.9637767637733612
# Lowering LR to 6.25e-06
#
# Epoch 00048: full_multi_label_metric improved from 0.95467 to 0.95498, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9640523886029688
# Lowering LR to 6.25e-06
#
# Epoch 00049: full_multi_label_metric improved from 0.95498 to 0.95574, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9631990825142539
# Lowering LR to 3.125e-06
#
# Epoch 00050: full_multi_label_metric improved from 0.95574 to 0.96062, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9643765354854473
# Lowering LR to 3.125e-06
#
# Epoch 00051: full_multi_label_metric improved from 0.96062 to 0.96123, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9644357972528634
# Lowering LR to 3.125e-06
#
# Epoch 00052: full_multi_label_metric improved from 0.96123 to 0.96459, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9628844276792979
# Lowering LR to 3.125e-06
#
# Epoch 00053: full_multi_label_metric improved from 0.96459 to 0.96535, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9632552874518436
# Lowering LR to 3.125e-06
#
# Epoch 00054: full_multi_label_metric did not improve from 0.96535
# Validation AUC: 0.9635614023066351
# Lowering LR to 3.125e-06
#
# Epoch 00055: full_multi_label_metric did not improve from 0.96535
# Validation AUC: 0.9634792189526616
# Lowering LR to 3.125e-06
#
# Epoch 00056: full_multi_label_metric improved from 0.96535 to 0.96795, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9629319915297568
# Lowering LR to 3.125e-06
#
# Epoch 00057: full_multi_label_metric did not improve from 0.96795
# Validation AUC: 0.963939991774139
# Lowering LR to 3.125e-06
#
# Epoch 00058: full_multi_label_metric did not improve from 0.96795
# Validation AUC: 0.963455585063285
# Lowering LR to 3.125e-06
#
# Epoch 00059: full_multi_label_metric did not improve from 0.96795
# Validation AUC: 0.9632403142304632
# Lowering LR to 1.5625e-06
#
# Epoch 00060: full_multi_label_metric improved from 0.96795 to 0.97024, saving model to modelFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9635123542585533
# Lowering LR to 1.5625e-06
#
# Epoch 00061: full_multi_label_met
# Lowering LR to 6.25e-06
#
# Epoch 00045: full_multi_label_metric improved from 0.66300 to 0.66422, saving model to lateFusion_PA_split_0.hdf5
# Validation AUC: 0.9393678847288429
# Lowering LR to 6.25e-06
#
# Epoch 00046: full_multi_label_metric improved from 0.66422 to 0.66835, saving model to lateFusion_PA_split_0.hdf5
# Validation AUC: 0.938525841309972
# Lowering LR to 6.25e-06
#
# Epoch 00047: full_multi_label_metric improved from 0.66835 to 0.67903, saving model to lateFusion_PA_split_0.hdf5
# Validation AUC: 0.9387523517524338
# Lowering LR to 6.25e-06
#
# Epoch 00048: full_multi_label_metric did not improve from 0.67903
# Validation AUC: 0.9383988895430202
# Lowering LR to 6.25e-06
#
# Epoch 00049: full_multi_label_metric improved from 0.67903 to 0.68407, saving model to lateFusion_PA_split_0.hdf5
# Validation AUC: 0.9374854211899725
# Lowering LR to 3.125e-06
#
# Epoch 00050: full_multi_label_metric did not improve from 0.68407
# Validation AUC: 0.9383355941263651
# Lowering LR to 3.125e-06
#
# Epoch 00051: full_multi_label_metric did not improve from 0.68407
# Validation AUC: 0.9389025102356311
# Lowering LR to 3.125e-06
#
# Epoch 00052: full_multi_label_metric did not improve from 0.68407
# Validation AUC: 0.9386297547929908
# Lowering LR to 3.125e-06
#
# Epoch 00053: full_multi_label_metric improved from 0.68407 to 0.68712, saving model to lateFusion_PA_split_0.hdf5
# Validation AUC: 0.9379672440738498
# Lowering LR to 3.125e-06
#
# Epoch 00054: full_multi_label_metric did not improve from 0.68712
# Validation AUC: 0.9385917524890393
# Lowering LR to 3.125e-06
#
# Epoch 00055: full_multi_label_metric improved from 0.68712 to 0.69017, saving model to lateFusion_PA_split_0.hdf5
# Validation AUC: 0.9375096961596813
# Lowering LR to 3.125e-06
#
# Epoch 00056: full_multi_label_metric improved from 0.69017 to 0.70131, saving model to lateFusion_PA_split_0.hdf5
# Validation AUC: 0.9372805774224351
# Lowering LR to 3.125e-06
#
# Epoch 00057: full_multi_label_metric did not improve from 0.70131
# Validation AUC: 0.9378076282092361
# Lowering LR to 3.125e-06
#
# Epoch 00058: full_multi_label_metric did not improve from 0.70131
# Validation AUC: 0.9376411749125518
# Lowering LR to 3.125e-06
#
# Epoch 00059: full_multi_label_metric did not improve from 0.70131
# Validation AUC: 0.9378474921697656
# Lowering LR to 1.5625e-06
#
# Epoch 00060: full_multi_label_metric did not improve from 0.70131
# Validation AUC: 0.9373127271141581
# Lowering LR to 1.5625e-06
#
# Epoch 00061: full_multi_label_metric did not improve from 0.70131
# Validation AUC: 0.9370475479381687
# Lowering LR to 1.5625e-06
#
# Epoch 00062: full_multi_label_metric did not improve from 0.70131
# Validation AUC: 0.9364174111998267
# Lowering LR to 1.5625e-06
#
# Epoch 00063: full_multi_label_metric did not improve from 0.70131
# Validation AUC: 0.937314817917337
# Lowering LR to 1.5625e-06
#
# Epoch 00064: full_multi_label_metric did not improve from 0.70131
# Validation AUC: 0.9367831548082297
# Lowering LR to 1.5625e-06
#
# Epoch 00065: full_multi_label_metric did not improve from 0.70131
# Validation AUC: 0.9373092894078197
# Lowering LR to 1.5625e-06
#
# Epoch 00066: full_multi_label_metric improved from 0.70131 to 0.70620, saving model to lateFusion_PA_split_0.hdf5
# Validation AUC: 0.9367231824520358
# Lowering LR to 1.5625e-06
#
# Epoch 00067: full_multi_label_metric did not improve from 0.70620
# Validation AUC: 0.9364190103818132
# Lowering LR to 1.5625e-06
#
# Epoch 00068: full_multi_label_metric improved from 0.70620 to 0.70971, saving model to lateFusion_PA_split_0.hdf5
# Validation AUC: 0.9367900075311457
# Lowering LR to 1.5625e-06
#
# Epoch 00069: full_multi_label_metric did not improve from 0.70971
# Validation AUC: 0.9364050582974898
# Lowering LR to 7.8125e-07
#
# Epoch 00070: full_multi_label_metric did not improve from 0.70971
# Validation AUC: 0.9364265290307882
# Lowering LR to 7.8125e-07
#
# Epoch 00071: full_multi_label_metric did not improve from 0.70971
# Validation AUC: 0.9366205792739911
# Lowering LR to 7.8125e-07
#
# Epoch 00072: full_multi_label_metric did not improve from 0.70971
# Validation AUC: 0.936469381399515
# Lowering LR to 7.8125e-07
#
# Epoch 00073: full_multi_label_metric improved from 0.70971 to 0.71001, saving model to lateFusion_PA_split_0.hdf5
# Validation AUC: 0.936130455497281
# Lowering LR to 7.8125e-07
#
# Epoch 00074: full_multi_label_metric improved from 0.71001 to 0.71337, saving model to lateFusion_PA_split_0.hdf5
# Validation AUC: 0.9368693565536083
# Lowering LR to 7.8125e-07
#
# Epoch 00075: full_multi_label_metric did not improve from 0.71337
# Validation AUC: 0.9369859625787473
# Lowering LR to 7.8125e-07
#
# Epoch 00076: full_multi_label_metric did not improve from 0.71337
# Validation AUC: 0.9367081405360129
# Lowering LR to 7.8125e-07
#
# Epoch 00077: full_multi_label_metric did not improve from 0.71337
# Validation AUC: 0.9372490669971892
# Lowering LR to 7.8125e-07
#
# Epoch 00078: full_multi_label_metric improved from 0.71337 to 0.71383, saving model to lateFusion_PA_split_0.hdf5
# Validation AUC: 0.9355418285007532
# Lowering LR to 7.8125e-07
#
# Epoch 00079: full_multi_label_metric did not improve from 0.71383
# Validation AUC: 0.9361794249681225
# Lowering LR to 3.90625e-07
#
# Epoch 00080: full_multi_label_metric improved from 0.71383 to 0.71764, saving model to lateFusion_PA_split_0.hdf5
# Validation AUC: 0.9370879594477937
# Weighted AUC score for split 0: 0.9474778730668943

# %% [markdown]
# ## Late Fusion Pretrained

# %%
weightedAUCList = []
AUCList = []
for ix, split in data.items():
    K.clear_session()
    print('====================Starting Split Number {}===================='.format(ix))
    model = Generate_Model(model_type='LateFusion')#create model
    model.compile(optimizer=optimizerFactory(), loss='binary_crossentropy', metrics=[full_multi_label_metric])
    
    train_generator = padchestDataGenerator_DF(df.iloc[split['train']].reset_index(drop=True), **params)
    valid_generator = padchestDataGenerator_DF(df.iloc[split['valid']].reset_index(drop=True), **params)
    test_generator = padchestDataGenerator_DF(df.iloc[split['test']].reset_index(drop=True), **params)
    #checkpoint
    filename = 'lateFusion_PT_{}_split_{}.hdf5'.format(projection,ix)
    checkpoint = getCheckpointCallback(filename)
    
    #Load weights: This will only load the feature extractors, not the 2 dense layers at the end.
    model.layers[3].set_weights(load_model('imageOnly_{}_split_{}.hdf5'.format(projection,ix),compile=False).layers[1].get_weights())#image
    model.layers[4].set_weights(load_model('textOnly_{}_split_{}.hdf5'.format(projection,ix),compile=False).layers[2].get_weights())#text
    
    #Fit Model
    model.fit_generator(train_generator, steps_per_epoch=len(train_generator), validation_data=valid_generator, 
                        validation_steps=len(valid_generator), workers=workers, epochs=n_epochs, verbose=fitVerbose, class_weight=train_generator.labels_weights, 
                        callbacks=[checkpoint,lrate, AUC(valid_generator)])
    y_hat = model.predict_generator(test_generator, steps=len(test_generator), workers=workers)
    auc = roc_auc_score(test_generator.mlb.transform(df.iloc[split['test']].iloc[:len(y_hat)]['Final_Labels']), y_hat, average=None)
    AUCList.append(auc)
    weighted_auc = roc_auc_score(test_generator.mlb.transform(df.iloc[split['test']].iloc[:len(y_hat)]['Final_Labels']), y_hat, average='weighted')
    weightedAUCList.append(weighted_auc)
    print('Weighted AUC score for split {}: {}'.format(ix,weighted_auc))
AUC_Scores = pd.DataFrame({'Label': test_generator.mlb.classes_, 'Score': np.mean(AUCList, axis=0)}, columns=['Label', 'Score'])
AUC_Scores = AUC_Scores.append({'Label': 'weighted_auc', 'Score':np.mean(weightedAUCList, axis=0)}, ignore_index=True)#to csv    
AUC_Scores.to_csv('AUC_scores_lateFusion_PT_{}'.format(projection))
# Out:
# ====================Starting Split Number 0====================
# Encoding Labels
# You have passed in a tokenizer, we will just convert to sequences
# filtering sentences
# filtering sents and removing stopwords
# Encoding Labels
# You have passed in a tokenizer, we will just convert to sequences
# filtering sentences
# filtering sents and removing stopwords
# Encoding Labels
# You have passed in a tokenizer, we will just convert to sequences
# filtering sentences
# filtering sents and removing stopwords
# Lowering LR to 0.0001
#
# Epoch 00001: full_multi_label_metric improved from -inf to 0.04686, saving model to lateFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9166832140042581
# Lowering LR to 0.0001
#
# Epoch 00002: full_multi_label_metric improved from 0.04686 to 0.23764, saving model to lateFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9238844831840631
# Lowering LR to 0.0001
#
# Epoch 00003: full_multi_label_metric improved from 0.23764 to 0.40293, saving model to lateFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9346871405774114
# Lowering LR to 0.0001
#
# Epoch 00004: full_multi_label_metric improved from 0.40293 to 0.47726, saving model to lateFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9393480604657742
# Lowering LR to 0.0001
#
# Epoch 00005: full_multi_label_metric improved from 0.47726 to 0.49863, saving model to lateFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9381598431050165
# Lowering LR to 0.0001
#
# Epoch 00006: full_multi_label_metric improved from 0.49863 to 0.51343, saving model to lateFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9450315009890401
# Lowering LR to 0.0001
#
# Epoch 00007: full_multi_label_metric improved from 0.51343 to 0.51709, saving model to lateFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9458745160379856
# Lowering LR to 0.0001
#
# Epoch 00008: full_multi_label_metric improved from 0.51709 to 0.52778, saving model to lateFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9513546176777157
# Lowering LR to 0.0001
#
# Epoch 00009: full_multi_label_metric improved from 0.52778 to 0.52915, saving model to lateFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9527299906797054
# Lowering LR to 5e-05
#
# Epoch 00010: full_multi_label_metric improved from 0.52915 to 0.55846, saving model to lateFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.951932195151472
# Lowering LR to 5e-05
#
# Epoch 00011: full_multi_label_metric improved from 0.55846 to 0.56792, saving model to lateFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9540229105685315
# Lowering LR to 5e-05
#
# Epoch 00012: full_multi_label_metric improved from 0.56792 to 0.57585, saving model to lateFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9495849825784225
# Lowering LR to 5e-05
#
# Epoch 00013: full_multi_label_metric improved from 0.57585 to 0.58501, saving model to lateFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9530639813802498
# Lowering LR to 5e-05
#
# Epoch 00014: full_multi_label_metric improved from 0.58501 to 0.59661, saving model to lateFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9451960512360695
# Lowering LR to 5e-05
#
# Epoch 00015: full_multi_label_metric improved from 0.59661 to 0.60272, saving model to lateFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9523682276891373
# Lowering LR to 5e-05
#
# Epoch 00016: full_multi_label_metric improved from 0.60272 to 0.62821, saving model to lateFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9484590808716356
# Lowering LR to 5e-05
#
# Epoch 00017: full_multi_label_metric improved from 0.62821 to 0.63172, saving model to lateFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9536283821301713
# Lowering LR to 5e-05
#
# Epoch 00018: full_multi_label_metric improved from 0.63172 to 0.63477, saving model to lateFusion_PT_PA_split_0.hdf5
# Validation AUC: 0.9525674479908256
# Lowering LR to 5e-05
#
# Epoch 00019: full_multi_label_metric improved from 0
# Lowering LR to 1.5625e-06
#
# Epoch 00066: full_multi_label_metric did not improve from 0.98626
# Validation AUC: 0.9774780494052094
# Lowering LR to 1.5625e-06
#
# Epoch 00067: full_multi_label_metric improved from 0.98626 to 0.98672, saving model to earlyFusion_PA_split_0.hdf5
# Validation AUC: 0.9772820553089048
# Lowering LR to 1.5625e-06
#
# Epoch 00068: full_multi_label_metric did not improve from 0.98672
# Validation AUC: 0.9770458197861098
# Lowering LR to 1.5625e-06
#
# Epoch 00069: full_multi_label_metric did not improve from 0.98672
# Validation AUC: 0.977446696548387
# Lowering LR to 7.8125e-07
#
# Epoch 00070: full_multi_label_metric did not improve from 0.98672
# Validation AUC: 0.976967218477535
# Lowering LR to 7.8125e-07
#
# Epoch 00071: full_multi_label_metric did not improve from 0.98672
# Validation AUC: 0.976927625218803
# Lowering LR to 7.8125e-07
#
# Epoch 00072: full_multi_label_metric improved from 0.98672 to 0.98764, saving model to earlyFusion_PA_split_0.hdf5
# Validation AUC: 0.9771973772524412
# Lowering LR to 7.8125e-07
#
# Epoch 00073: full_multi_label_metric improved from 0.98764 to 0.98779, saving model to earlyFusion_PA_split_0.hdf5
# Validation AUC: 0.9767806000030952
# Lowering LR to 7.8125e-07
#
# Epoch 00074: full_multi_label_metric did not improve from 0.98779
# Validation AUC: 0.9767580751712085
# Lowering LR to 7.8125e-07
#
# Epoch 00075: full_multi_label_metric improved from 0.98779 to 0.98855, saving model to earlyFusion_PA_split_0.hdf5
# Validation AUC: 0.9767327983163892
# Lowering LR to 7.8125e-07
#
# Epoch 00076: full_multi_label_metric did not improve from 0.98855
# Validation AUC: 0.9768064490003526
# Lowering LR to 7.8125e-07
#
# Epoch 00077: full_multi_label_metric did not improve from 0.98855
# Validation AUC: 0.9768660045282727
# Lowering LR to 7.8125e-07
#
# Epoch 00078: full_multi_label_metric did not improve from 0.98855
# Validation AUC: 0.976623811968997
# Lowering LR to 7.8125e-07
#
# Epoch 00079: full_multi_label_metric did not improve from 0.98855
# Validation AUC: 0.9769527875690811
# Lowering LR to 3.90625e-07
#
# Epoch 00080: full_multi_label_metric improved from 0.98855 to 0.98901, saving model to earlyFusion_PA_split_0.hdf5
# Validation AUC: 0.9767447859212972
# Weighted AUC score for split 0: 0.9801232505126506

# %% [markdown]
# ## Early Fusion (Wide)

# %%
weightedAUCList = []
AUCList = []
for ix, split in data.items():
    K.clear_session()
    print('====================Starting Split Number {}===================='.format(ix))
    model = Generate_Model(model_type='EarlyFusion_Wide')
    model.compile(optimizer=optimizerFactory(), loss='binary_crossentropy', metrics=[full_multi_label_metric])
    
    train_generator = padchestDataGenerator_DF(df.iloc[split['train']].reset_index(drop=True), **params)
    valid_generator = padchestDataGenerator_DF(df.iloc[split['valid']].reset_index(drop=True), **params)
    test_generator = padchestDataGenerator_DF(df.iloc[split['test']].reset_index(drop=True), **params)
    #checkpoint
    filename = 'earlyFusion_wide_{}_split_{}.hdf5'.format(projection,ix)#'imageOnly_lat.hdf5'
    checkpoint = getCheckpointCallback(filename)
    model.fit_generator(train_generator, steps_per_epoch=len(train_generator), validation_data=valid_generator, 
                        validation_steps=len(valid_generator), workers=workers, epochs=n_epochs, verbose=fitVerbose, class_weight=train_generator.labels_weights, 
                        callbacks=[checkpoint,lrate, AUC(valid_generator)])
    y_hat = model.predict_generator(test_generator, steps=len(test_generator), workers=workers)
    auc = roc_auc_score(test_generator.mlb.transform(df.iloc[split['test']].iloc[:len(y_hat)]['Final_Labels']), y_hat, average=None)
    AUCList.append(auc)
    weighted_auc = roc_auc_score(test_generator.mlb.transform(df.iloc[split['test']].iloc[:len(y_hat)]['Final_Labels']), y_hat, average='weighted')
    weightedAUCList.append(weighted_auc)
    print('Weighted AUC score for split {}: {}'.format(ix,weighted_auc))
AUC_Scores = pd.DataFrame({'Label': test_generator.mlb.classes_, 'Score': np.mean(AUCList, axis=0)}, columns=['Label', 'Score'])
AUC_Scores = AUC_Scores.append({'Label': 'weighted_auc', 'Score':np.mean(weightedAUCList, axis=0)}, ignore_index=True)#to csv    
AUC_Scores.to_csv('AUC_scores_earlyFusion_wide_{}'.format(projection))
# Out:
# ====================Starting Split Number 0====================
# Encoding Labels
# You have passed in a tokenizer, we will just convert to sequences
# filtering sentences
# filtering sents and removing stopwords
# Encoding Labels
# You have passed in a tokenizer, we will just convert to sequences
# filtering sentences
# filtering sents and removing stopwords
# Encoding Labels
# You have passed in a tokenizer, we will just convert to sequences
# filtering sentences
# filtering sents and removing stopwords
# Lowering LR to 0.0001
#
# Epoch 00001: full_multi_label_metric improved from -inf to 0.00687, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.7514203389089252
# Lowering LR to 0.0001
#
# Epoch 00002: full_multi_label_metric improved from 0.00687 to 0.05708, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.8008940211557797
# Lowering LR to 0.0001
#
# Epoch 00003: full_multi_label_metric improved from 0.05708 to 0.20009, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.8239444236945098
# Lowering LR to 0.0001
#
# Epoch 00004: full_multi_label_metric improved from 0.20009 to 0.28495, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.8519790574268262
# Lowering LR to 0.0001
#
# Epoch 00005: full_multi_label_metric improved from 0.28495 to 0.34096, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.8781743995202557
# Lowering LR to 0.0001
#
# Epoch 00006: full_multi_label_metric improved from 0.34096 to 0.37088, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.8968222078892747
# Lowering LR to 0.0001
#
# Epoch 00007: full_multi_label_metric improved from 0.37088 to 0.39438, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.9124130465607484
# Lowering LR to 0.0001
#
# Epoch 00008: full_multi_label_metric improved from 0.39438 to 0.41606, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.9209643373536426
# Lowering LR to 0.0001
#
# Epoch 00009: full_multi_label_metric improved from 0.41606 to 0.43254, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.9262958034001398
# Lowering LR to 5e-05
#
# Epoch 00010: full_multi_label_metric improved from 0.43254 to 0.44551, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.9303786658232712
# Lowering LR to 5e-05
#
# Epoch 00011: full_multi_label_metric improved from 0.44551 to 0.45742, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.9333271968723051
# Lowering LR to 5e-05
#
# Epoch 00012: full_multi_label_metric improved from 0.45742 to 0.46352, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.9354967161640115
# Lowering LR to 5e-05
#
# Epoch 00013: full_multi_label_metric improved from 0.46352 to 0.47176, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.9371774359377484
# Lowering LR to 5e-05
#
# Epoch 00014: full_multi_label_metric improved from 0.47176 to 0.48062, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.9380836527242198
# Lowering LR to 5e-05
#
# Epoch 00015: full_multi_label_metric improved from 0.48062 to 0.48901, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.9402895350838214
# Lowering LR to 5e-05
#
# Epoch 00016: full_multi_label_metric improved from 0.48901 to 0.50351, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.9416950038573718
# Lowering LR to 5e-05
#
# Epoch 00017: full_multi_label_metric improved from 0.50351 to 0.50626, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.9452992182260238
# Lowering LR to 5e-05
#
# Epoch 00018: full_multi_label_metric improved from 0.50626 to 0.51618, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.9472601632968789
# Lowering LR to 5e-05
#
# Epoch 00019: full_multi_label_metric improved from 0.51618 to 0.51740, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.9492400682356358
# Lowering LR to 2.5e-05
#
# Epoch 00020: full_multi_label_metric improved from 0.51740 to 0.53068, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.9473101178196777
# Lowering LR to 2.5e-05
#
# Epoch 00021: full_multi_label_metric improved from 0.53068 to 0.53556, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.9495242877670911
# Lowering LR to 2.5e-05
#
# Epoch 00022: full_multi_label_metric improved from 0.53556 to 0.54182, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.9497384139232857
# Lowering LR to 2.5e-05
#
# Epoch 00023: full_multi_label_metric did not improve from 0.54182
# Validation AUC: 0.949907269897422
# Lowering LR to 2.5e-05
#
# Epoch 00024: full_multi_label_metric improved from 0.54182 to 0.55021, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.9503339168791874
# Lowering LR to 2.5e-05
#
# Epoch 00025: full_multi_label_metric did not improve from 0.55021
# Validation AUC: 0.9510738951800112
# Lowering LR to 2.5e-05
#
# Epoch 00026: full_multi_label_metric improved from 0.55021 to 0.55067, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.950667332427988
# Lowering LR to 2.5e-05
#
# Epoch 00027: full_multi_label_metric improved from 0.55067 to 0.55479, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.9524519247869434
# Lowering LR to 2.5e-05
#
# Epoch 00028: full_multi_label_metric improved from 0.55479 to 0.55540, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.9518043856288957
# Lowering LR to 2.5e-05
#
# Epoch 00029: full_multi_label_metric improved from 0.55540 to 0.56044, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.9526200783743092
# Lowering LR to 1.25e-05
#
# Epoch 00030: full_multi_label_metric improved from 0.56044 to 0.57799, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.9531962834211023
# Lowering LR to 1.25e-05
#
# Epoch 00031: full_multi_label_metric did not improve from 0.57799
# Validation AUC: 0.9536152479923378
# Lowering LR to 1.25e-05
#
# Epoch 00032: full_multi_label_metric improved from 0.57799 to 0.57814, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.9535804394183809
# Lowering LR to 1.25e-05
#
# Epoch 00033: full_multi_label_metric did not improve from 0.57814
# Validation AUC: 0.9540464074860293
# Lowering LR to 1.25e-05
#
# Epoch 00034: full_multi_label_metric improved from 0.57814 to 0.59066, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.9532243632535671
# Lowering LR to 1.25e-05
#
# Epoch 00035: full_multi_label_metric did not improve from 0.59066
# Validation AUC: 0.9534868409371016
# Lowering LR to 1.25e-05
#
# Epoch 00036: full_multi_label_metric improved from 0.59066 to 0.59081, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.954574639507821
# Lowering LR to 1.25e-05
#
# Epoch 00037: full_multi_label_metric did not improve from 0.59081
# Validation AUC: 0.9544983466339937
# Lowering LR to 1.25e-05
#
# Epoch 00038: full_multi_label_metric did not improve from 0.59081
# Validation AUC: 0.954655596692579
# Lowering LR to 1.25e-05
#
# Epoch 00039: full_multi_label_metric improved from 0.59081 to 0.59173, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.9545155631549969
# Lowering LR to 6.25e-06
#
# Epoch 00040: full_multi_label_metric improved from 0.59173 to 0.59402, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.9549193789214264
# Lowering LR to 6.25e-06
#
# Epoch 00041: full_multi_label_metric improved from 0.59402 to 0.60211, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.9556956841213972
# Lowering LR to 6.25e-06
#
# Epoch 00042: full_multi_label_metric did not improve from 0.60211
# Validation AUC: 0.9551970623739632
# Lowering LR to 6.25e-06
#
# Epoch 00043: full_multi_label_metric improved from 0.60211 to 0.60317, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.9555296205198873
# Lowering LR to 6.25e-06
#
# Epoch 00044: full_multi_label_metric improved from 0.60317 to 0.60394, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.9557804401882676
# Lowering LR to 6.25e-06
#
# Epoch 00045: full_multi_label_metric did not improve from 0.60394
# Validation AUC: 0.9560141592456659
# Lowering LR to 6.25e-06
#
# Epoch 00046: full_multi_label_metric did not improve from 0.60394
# Validation AUC: 0.9559207602451252
# Lowering LR to 6.25e-06
#
# Epoch 00047: full_multi_label_metric improved from 0.60394 to 0.60485, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.956077948276763
# Lowering LR to 6.25e-06
#
# Epoch 00048: full_multi_label_metric improved from 0.60485 to 0.60577, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.9556091312188274
# Lowering LR to 6.25e-06
#
# Epoch 00049: full_multi_label_metric did not improve from 0.60577
# Validation AUC: 0.95595048409412
# Lowering LR to 3.125e-06
#
# Epoch 00050: full_multi_label_metric did not improve from 0.60577
# Validation AUC: 0.9562276450615312
# Lowering LR to 3.125e-06
#
# Epoch 00051: full_multi_label_metric improved from 0.60577 to 0.61142, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.9564973282151344
# Lowering LR to 3.125e-06
#
# Epoch 00052: full_multi_label_metric did not improve from 0.61142
# Validation AUC: 0.9561170868238188
# Lowering LR to 3.125e-06
#
# Epoch 00053: full_multi_label_metric improved from 0.61142 to 0.61447, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.9560696168035471
# Lowering LR to 3.125e-06
#
# Epoch 00054: full_multi_label_metric did not improve from 0.61447
# Validation AUC: 0.9560925680305812
# Lowering LR to 3.125e-06
#
# Epoch 00055: full_multi_label_metric did not improve from 0.61447
# Validation AUC: 0.9568216350971923
# Lowering LR to 3.125e-06
#
# Epoch 00056: full_multi_label_metric improved from 0.61447 to 0.61645, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.9568927980742961
# Lowering LR to 3.125e-06
#
# Epoch 00057: full_multi_label_metric did not improve from 0.61645
# Validation AUC: 0.9568591352960506
# Lowering LR to 3.125e-06
#
# Epoch 00058: full_multi_label_metric did not improve from 0.61645
# Validation AUC: 0.9569453369183997
# Lowering LR to 3.125e-06
#
# Epoch 00059: full_multi_label_metric did not improve from 0.61645
# Validation AUC: 0.9569564519345269
# Lowering LR to 1.5625e-06
#
# Epoch 00060: full_multi_label_metric did not improve from 0.61645
# Validation AUC: 0.9566600943025301
# Lowering LR to 1.5625e-06
#
# Epoch 00061: full_multi_label_metric did not improve from 0.61645
# Validation AUC: 0.9574976216182457
# Lowering LR to 1.5625e-06
#
# Epoch 00062: full_multi_label_metric did not improve from 0.61645
# Validation AUC: 0.9567745682156173
# Lowering LR to 1.5625e-06
#
# Epoch 00063: full_multi_label_metric did not improve from 0.61645
# Validation AUC: 0.9570459188445913
# Lowering LR to 1.5625e-06
#
# Epoch 00064: full_multi_label_metric improved from 0.61645 to 0.61935, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.9570925075580348
# Lowering LR to 1.5625e-06
#
# Epoch 00065: full_multi_label_metric did not improve from 0.61935
# Validation AUC: 0.9564510846294373
# Lowering LR to 1.5625e-06
#
# Epoch 00066: full_multi_label_metric did not improve from 0.61935
# Validation AUC: 0.9567731965280686
# Lowering LR to 1.5625e-06
#
# Epoch 00067: full_multi_label_metric did not improve from 0.61935
# Validation AUC: 0.9572839271792388
# Lowering LR to 1.5625e-06
#
# Epoch 00068: full_multi_label_metric did not improve from 0.61935
# Validation AUC: 0.9573977112296034
# Lowering LR to 1.5625e-06
#
# Epoch 00069: full_multi_label_metric did not improve from 0.61935
# Validation AUC: 0.9568664246441969
# Lowering LR to 7.8125e-07
#
# Epoch 00070: full_multi_label_metric did not improve from 0.61935
# Validation AUC: 0.9570873715077898
# Lowering LR to 7.8125e-07
#
# Epoch 00071: full_multi_label_metric improved from 0.61935 to 0.62408, saving model to earlyFusion_wide_PA_split_0.hdf5
# Validation AUC: 0.9567925775897961
# Lowering LR to 7.8125e-07
#
# Epoch 00072: full_multi_label_metric did not improve from 0.62408
# Validation AUC: 0.9570992011212368
# Lowering LR to 7.8125e-07
#
# Epoch 00073: full_multi_label_metric did not improve from 0.62408
# Validation AUC: 0.9567354735854623
# Lowering LR to 7.8125e-07
#
# Epoch 00074: full_multi_label_metric did not improve from 0.62408
# Validation AUC: 0.9571117132787228
# Lowering LR to 7.8125e-07
#
# Epoch 00075: full_multi_label_metric did not improve from 0.62408
# Validation AUC: 0.9579262906270871
# Lowering LR to 7.8125e-07
#
# Epoch 00076: full_multi_label_metric did not improve from 0.62408
# Validation AUC: 0.9568885555831061
# Lowering LR to 7.8125e-07
#
# Epoch 00077: full_multi_label_metric did not improve from 0.62408
# Validation AUC: 0.9576146980870233
# Lowering LR to 7.8125e-07
#
# Epoch 00078: full_multi_label_metric did not improve from 0.62408
# Validation AUC: 0.9566212202581499
# Lowering LR to 7.8125e-07
#
# Epoch 00079: full_multi_label_metric did not improve from 0.62408
# Validation AUC: 0.9565212255286701
# Lowering LR to 3.90625e-07
#
# Epoch 00080: full_multi_label_metric did not improve from 0.62408
# Validation AUC: 0.9569119192389276
# Weighted AUC score for split 0: 0.9640188128180177
